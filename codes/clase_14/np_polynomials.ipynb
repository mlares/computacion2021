# %%
from numpy.polynomial import polynomial as P
import numpy as np
from matplotlib import pyplot as plt

# %%
coefs = P.polyfromroots([1, 2])

# %%
x = np.linspace(0, 3)

# %%
y = P.polyval(x, coefs)

# %%
plt.plot(x, y)
plt.grid()

# %%
coefs
# Out:
# array([ 2., -3.,  1.])
