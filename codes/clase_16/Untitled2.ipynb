# %%
import numpy as np
import math
from matplotlib import pyplot as plt

# %%
def f(x):
    z = -2*x*np.exp(-x**2)
    return 2/np.sqrt(math.pi) * z

# %%
x = np.linspace(-3, 3, 200)

# %%
y = f(x)

# %%
plt.plot(x, y)
